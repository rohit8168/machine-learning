# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns

# %%
data=pd.read_csv(r"C:\ml\da\mnist_train.csv")
l=data['label']
data=data.drop("label",axis=1)

# %%
from sklearn.preprocessing import StandardScaler
data=StandardScaler().fit_transform(data)

# %%
data_1000=data[0:1000,:]
label_1000=l[0:1000]

# %%
model=TSNE(n_components=2,random_state=0)
tsne_data=model.fit_transform(data_1000)
tsne_data=pd.DataFrame(tsne_data,columns=["Dim_1","Dim_2"])
tsne_df=pd.concat((tsne_data,label_1000),axis=1)
tsne_df
# Out:
#          Dim_1      Dim_2  label
# 0    19.194315  34.716633      5
# 1   -15.911439  32.242298      0
# 2    -1.566831 -42.070393      4
# 3    22.520079   0.300000      1
# 4   -17.084650 -31.745642      9
# ..         ...        ...    ...
# 995  17.557556 -34.666080      7
# 996 -25.414305   8.978918      6
# 997  -9.322487  35.928509      0
# 998  -5.627628  13.031551      3
# 999 -35.838612  18.777945      6
#
# [1000 rows x 3 columns]

# %%
sns.FacetGrid(tsne_df,hue="label").map(plt.scatter,"Dim_1","Dim_2").add_legend()
